# %%
"""Check and clean the data here."""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu, spearmanr
import statsmodels.formula.api as smf
import importlib
import clean_function as cf
import data_analysis as da

importlib.reload(cf)
importlib.reload(da)

import pandas as pd

pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_columns", None)   # show all columns
pd.set_option("display.width", None)         # don't wrap lines

# %%
# Load datasets
df1 = pd.read_csv("bat_data_cleaned.csv")
df2 = pd.read_csv("rat_data_cleaned.csv")

# %%
# Run all Investigation A analyses
result = da.run_investigation_a(df1, df2)
if "summary" in result:
    print(f"Logistic Regression ({result['dataset']} dataset):")
    print(result["summary"])
else:
    print(result)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# {'descriptive': {'dataset1_shape': (906, 12), 'dataset2_shape': (2123, 7), 'dataset1_desc':                  start_time  bat_landing_to_food habit     rat_period_start       rat_period_end  seconds_after_rat_arrival        risk      reward       month          sunset_time  hours_after_sunset  season
# count                   906           906.000000   906                  906                  906                 906.000000  906.000000  906.000000  906.000000                  906          906.000000   906.0
# unique                  628                  NaN    57                  268                  268                        NaN         NaN         NaN         NaN                   65                 NaN     NaN
# ...

# %%
# Print results
# Print results nicely
print("Descriptive Stats ")
print(result["descriptive"]["dataset1_shape"], result["descriptive"]["dataset2_shape"])

print("\nCorrelation Analysis")
print(result["correlation"])

print("\nGroup Comparison")
print(result["group_comparison"])

print("\nLogistic Regression")
print(result["regression"])
# Out:
# Descriptive Stats
# (906, 12) (2123, 7)
#
# Correlation Analysis
# {'corr_rat_vs_delay': np.float64(nan), 'corr_rat_vs_risk': np.float64(nan), 'corr_rat_minutes_vs_delay': np.float64(nan), 'corr_rat_minutes_vs_risk': np.float64(nan)}
#
# Group Comparison
# {'group0_mean_delay': np.float64(0.0355201955966737), 'group1_mean_delay': nan, 'group0_mean_risk': np.float64(1.0), 'group1_mean_risk': nan}
#
# Logistic Regression
# ...
