# %%
"""Check and clean the data here."""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu, spearmanr
import statsmodels.formula.api as smf
import importlib
import clean_function as cf
import data_analysis as da

importlib.reload(cf)
importlib.reload(da)

import pandas as pd

pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_columns", None)   # show all columns
pd.set_option("display.width", None)         # don't wrap lines

# %%
# Load datasets
df1 = pd.read_csv("bat_data_cleaned.csv")
df2 = pd.read_csv("rat_data_cleaned.csv")

# %%
# Load datasets using your helper
df1, df2 = da.load_and_clean_data("dataset1.csv", "dataset2.csv")
# Out:
# c:\GitHub\bat-vs-rat\data_analysis.py:28: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   # ====================================================
# c:\GitHub\bat-vs-rat\data_analysis.py:28: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   # ====================================================
# c:\GitHub\bat-vs-rat\data_analysis.py:28: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   # ====================================================
# c:\GitHub\bat-vs-rat\data_analysis.py:28: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   # ====================================================
# c:\GitHub\bat-vs-rat\data_analysis.py:31: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return {
# c:\GitHub\bat-vs-rat\data_analysis.py:73: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   "corr_rat_minutes_vs_delay": merged["rat_minutes"].corr(merged["mean_bat_landing_to_food"]),
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# c:\GitHub\bat-vs-rat\data_analysis.py:73: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   "corr_rat_minutes_vs_delay": merged["rat_minutes"].corr(merged["mean_bat_landing_to_food"]),
# c:\GitHub\bat-vs-rat\data_analysis.py:237: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# c:\GitHub\bat-vs-rat\data_analysis.py:187: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   # Seasonal Effect
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 5
#       2 df1, df2 = da.load_and_clean_data("dataset1.csv", "dataset2.csv")
#       4 # Run the full investigation
# ----> 5 results = da.run_investigation_a(df1, df2)
#       7 # Print results nicely
#       8 for k, v in results.items():
#
# File c:\GitHub\bat-vs-rat\data_analysis.py:258, in run_investigation_a(df1, df2)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\GitHub\bat-vs-rat\data_analysis.py:187, in plot_by_season(merged)
#     184 plt.title("Time After Rat Arrival vs Bat Landing Response")
#     185 plt.show()
# --> 187 # Seasonal Effect
#     188 sns.countplot(x="season", hue="risk", data=df1)
#     189 plt.title("Seasonal Risk Behavior")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.
