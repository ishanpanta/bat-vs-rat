# %%
"""Check and clean the data here."""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu, spearmanr
import statsmodels.formula.api as smf
import importlib
import clean_function as cf
import data_analysis as da

importlib.reload(cf)
importlib.reload(da)

import pandas as pd

pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_columns", None)   # show all columns
pd.set_option("display.width", None)         # don't wrap lines

# %%
# Load datasets
df1 = pd.read_csv("bat_data_cleaned.csv")
df2 = pd.read_csv("rat_data_cleaned.csv")

# %%
# Load datasets using your helper
df1, df2 = da.load_and_clean_data("dataset1.csv", "dataset2.csv")

# Run the full investigation
results = da.run_investigation_a(df1, df2)

# Print results nicely
for k, v in results.items():
    print(f"\n=== {k.upper()} ===")
    print(v)
# Out:
# c:\GitHub\bat-vs-rat\data_analysis.py:235: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Risk-taking behavior rate:
#  risk
# 0    50.496141
# 1    49.503859
# Name: proportion, dtype: float64
# === DESCRIPTIVE ===
# {'dataset1_shape': (907, 12), 'dataset2_shape': (2123, 7), 'dataset1_desc':                            start_time  bat_landing_to_food habit               rat_period_start                 rat_period_end  seconds_after_rat_arrival        risk      reward  month                    sunset_time  hours_after_sunset  season
# count                             907           907.000000   866                            907                            907                 907.000000  907.000000  907.000000  907.0                            907          907.000000   907.0
# ...
